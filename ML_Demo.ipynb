# %%
from ml_module import LiR, LoR
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Test Regression
# df = pd.read_csv("Advertising.csv")
# X = df.drop("sales",axis=1)
# y = df["sales"]

# %%
# Standard ElasticNetCV model
# elastic_model = LiR(X=X, y=y, elasticNetCV=True)

# %%
# Test Binary Classifier
# df = pd.read_csv("hearing_test.csv")
# X = df.drop("test_result",axis=1)
# y = df["test_result"]

# %%
# Test Multi Class Classifier
df = pd.read_csv("iris.csv")
X = df.drop("species",axis=1)
y = df["species"]

# %%
# Standard CV model
logistic_model = LoR(X,y,logistic_cv=True, max_iter_cv=10_000)

# %%
# Gridsearch CV model
# logistic_model = LoR(X,y,logistic=True,max_iter_cv=10_000)

# %%
logistic_model.get_classification_report()
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        13
#   versicolor       1.00      1.00      1.00        20
#    virginica       1.00      1.00      1.00        12
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
# logistic_model.preparation_lor_func(train_anot=True, d=range(1,11))

# %%
logistic_model.count_plot(df)

# %%
# test_result for binary
# species for multi_class
logistic_model.heat_map(df,"species")

# %%
logistic_model.simple_confusion_matrix()
# Out:
# LoR_CV has a confusion matrix of
# [[13  0  0]
#  [ 0 20  0]
#  [ 0  0 12]]

# %%
logistic_model.confusion_matrix(normalize="true")

# %%
logistic_model.AUC_plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 logistic_model.AUC_plot()
#
# File c:\Users\Mecidon\OneDrive\Pythonprog\Classes\Machine Learning\lor_class.py:349, in LoR.AUC_plot(self)
#     345 def AUC_plot(self):
#     346     """
#     347     Plot AUC.
#     348     """
# --> 349     PrecisionRecallDisplay.from_estimator(estimator=self.model,
#     350                                           X=self.X_test,
#     351                                           y=self.y_test)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_plot\precision_recall_curve.py:348, in PrecisionRecallDisplay.from_estimator(cls, estimator, X, y, sample_weight, pos_label, drop_intermediate, response_method, name, ax, plot_chance_level, chance_level_kw, **kwargs)
# ...

# %%
logistic_model.ROC_plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 logistic_model.ROC_plot()
#
# File c:\Users\Mecidon\OneDrive\Pythonprog\Classes\Machine Learning\lor_class.py:257, in LoR.ROC_plot(self)
#     256 def ROC_plot(self):
# --> 257     RocCurveDisplay.from_estimator(estimator=self.model,
#     258                                    X=self.X_test,
#     259                                    y=self.y_test)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_plot\roc_curve.py:275, in RocCurveDisplay.from_estimator(cls, estimator, X, y, sample_weight, drop_intermediate, response_method, pos_label, name, ax, plot_chance_level, chance_level_kw, **kwargs)
#     175 @classmethod
#     176 def from_estimator(
#     177     cls,
#    (...)
#     190     **kwargs,
# ...

# %%
logistic_model.export_model()

# %%
logistic_model.plot_3d_scatter(df, "sepal_width", "petal_width", "petal_length", "species")
# logistic_model_cv.plot_3d_scatter(df=df, x_col="age", y_col="physical_score",target_col="test_result")

# %%
logistic_model.plot_multiclass_roc(n_classes=3)
